# %% [markdown]
# # Combined CSV

# %%
import os
import pandas as pd

# Folder containing CSV files
folder_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\each_person_csv"
output_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\test"

# %%
import os
import pandas as pd

# %%
# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.lower().endswith(".csv")]

# Read and combine
df_list = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

# Concatenate into one DataFrame
combined_df = pd.concat(df_list, ignore_index=True)

# Save to a single CSV
output_path = os.path.join(folder_path, "combined_test.csv")
combined_df.to_csv(output_path, index=False)

print(f"✅ Combined {len(csv_files)} CSV files into {output_path}")
print(f"Total rows: {len(combined_df)}")
# Out:
# ✅ Combined 3 CSV files into D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\each_person_csv\combined_test.csv
# Total rows: 3898

# %%
# train
folder_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\each_person_train_csv"
output_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\train"

# %%
# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.lower().endswith(".csv")]

# Read and combine
df_list = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

# Concatenate into one DataFrame
combined_df = pd.concat(df_list, ignore_index=True)

# Save to a single CSV
output_path = os.path.join(folder_path, "combined_train.csv")
combined_df.to_csv(output_path, index=False)

print(f"✅ Combined {len(csv_files)} CSV files into {output_path}")
print(f"Total rows: {len(combined_df)}")
# Out:
# ✅ Combined 16 CSV files into D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\each_person_train_csv\combined_train.csv
# Total rows: 22886

# %% [markdown]
# # Check

# %%
df = pd.read_csv(r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\each_person_csv\combined_test.csv")
df
# Out:
#       patient_id  event_id   family         type  start_sec  duration_sec  \
# 0           1010         0     User         Gain        0.0           0.0
# 1           1010         1     User  ChannelFail        0.0          30.0
# 2           1010         2     User  ChannelFail        0.0           6.0
# 3           1010         3    Nasal        Snore       40.0           6.0
# 4           1010         4  Cardiac       LongRR       56.0           2.0
# ...          ...       ...      ...          ...        ...           ...
# 3893        1016       810  Cardiac      PttDrop    21554.0           9.0
# 3894        1016       811  Cardiac      PttDrop    21648.0          12.0
# 3895        1016       812     User  ChannelFail    21660.0          90.0
# 3896        1016       813  Cardiac      PttDrop    21768.0          12.0
# 3897        1016       814    Neuro      Arousal    21840.0           4.0
#
#       end_sec  segment_index  segment_local_start_sec  recording_start_iso
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Arousal                 704
# LongRR                  521
# Bradycardia             472
# RelativeDesaturation    451
# ObstructiveApnea        447
# Snore                   415
# PttDrop                 401
# ChannelFail             189
# Hypopnea                155
# Gain                     70
# Tachycardia              48
# MixedApnea               21
# CentralApnea              4
# Name: count, dtype: int64

# %%
df2 = pd.read_csv(r'D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\each_person_train_csv\combined_train.csv')

# %%
df2['type'].value_counts()
# Out:
# type
# LongRR                  4653
# Arousal                 4058
# PttDrop                 1839
# RelativeDesaturation    1810
# LegMovement             1785
# ObstructiveApnea        1766
# Bradycardia             1647
# Snore                   1394
# ChannelFail             1379
# Hypopnea                1164
# Tachycardia              663
# Gain                     450
# MixedApnea               225
# CentralApnea              53
# Name: count, dtype: int64

# %%
# กำหนด type ที่ต้องการเก็บ
keep_types = [ "Snore",'ObstructiveApnea']

# กรองข้อมูล"
df_filtered = df2[df2['type'].isin(keep_types)].reset_index(drop=True)

# บันทึกทับไฟล์เดิมหรือเป็นไฟล์ใหม่
output_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\train\use_train_osa.csv"
df_filtered.to_csv(output_path, index=False)

print(f"✅ Filtered CSV saved to {output_path}")
print(f"Remaining rows: {len(df_filtered)}")
print(df_filtered['type'].value_counts())
# Out:
# ✅ Filtered CSV saved to D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_train\train\use_train_osa.csv
# Remaining rows: 3160
# type
# ObstructiveApnea    1766
# Snore               1394
# Name: count, dtype: int64

# %%
# กำหนด type ที่ต้องการเก็บ
# keep_types = ["Hypopnea", "Snore", "MixedApnea", "CentralApnea",'ObstructiveApnea']
keep_types = [ "Snore",'ObstructiveApnea']

# กรองข้อมูล"
df_filtered = df[df['type'].isin(keep_types)].reset_index(drop=True)

# บันทึกทับไฟล์เดิมหรือเป็นไฟล์ใหม่
output_path = r"D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\test\use_test_osa.csv"
df_filtered.to_csv(output_path, index=False)

print(f"✅ Filtered CSV saved to {output_path}")
print(f"Remaining rows: {len(df_filtered)}")
print(df_filtered['type'].value_counts())
# Out:
# ✅ Filtered CSV saved to D:\V89\Snore_Apnea_Analyze\EDF_RML\data_csv\use_test\test\use_test_osa.csv
# Remaining rows: 862
# type
# ObstructiveApnea    447
# Snore               415
# Name: count, dtype: int64
